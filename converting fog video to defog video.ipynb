# %%
"""Single image dehazing."""
from __future__ import division
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

class Channel_value:
    val = -1.0
    intensity = -1.0


def find_intensity_of_atmospheric_light(img, gray):
    top_num = int(img.shape[0] * img.shape[1] * 0.001)
    toplist = [Channel_value()] * top_num
    dark_channel = find_dark_channel(img)

    for y in range(img.shape[0]):
        for x in range(img.shape[1]):
            val = img.item(y, x, dark_channel)
            intensity = gray.item(y, x)
            for t in toplist:
                if t.val < val or (t.val == val and t.intensity < intensity):
                    t.val = val
                    t.intensity = intensity
                    break

    max_channel = Channel_value()
    for t in toplist:
        if t.intensity > max_channel.intensity:
            max_channel = t

    return max_channel.intensity


def find_dark_channel(img):
    return np.unravel_index(np.argmin(img), img.shape)[2]


def clamp(minimum, x, maximum):
    return max(minimum, min(x, maximum))


def dehaze(img, light_intensity, windowSize, t0, w):
    size = (img.shape[0], img.shape[1])

    outimg = np.zeros(img.shape, img.dtype)

    for y in range(size[0]):
        for x in range(size[1]):
            x_low = max(x-(windowSize//2), 0)
            y_low = max(y-(windowSize//2), 0)
            x_high = min(x+(windowSize//2), size[1])
            y_high = min(y+(windowSize//2), size[0])

            sliceimg = img[y_low:y_high, x_low:x_high]

            dark_channel = find_dark_channel(sliceimg)
            t = 1.0 - (w * img.item(y, x, dark_channel) / light_intensity)

            outimg.itemset((y,x,0), clamp(0, ((img.item(y,x,0) - light_intensity) / max(t, t0) + light_intensity), 255))
            outimg.itemset((y,x,1), clamp(0, ((img.item(y,x,1) - light_intensity) / max(t, t0) + light_intensity), 255))
            outimg.itemset((y,x,2), clamp(0, ((img.item(y,x,2) - light_intensity) / max(t, t0) + light_intensity), 255))
    return outimg


def fogdet(inpath):
    imageName = inpath #eg. fg5.jpg
    img = cv2.imread(imageName)
    print(imageName)
    scale_percent = 50
    #calculate the 50 percent of original dimensions
    width = int(img.shape[1] * scale_percent / 100)
    height = int(img.shape[0] * scale_percent / 100)
    dsize = (width, height)
    img= cv2.resize(img, dsize)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    light_intensity = find_intensity_of_atmospheric_light(img, gray)
    w = 0.95
    t0 = 0.55
    outimg = dehaze(img, light_intensity, 20, t0, w)
    #cv2.imshow('sample image',outimg)
    name = imageName+'_out_t0'+str(t0)+'_wakk'+str(w)+'.jpg'
    cv2.imwrite(name, outimg)
    #cv2.waitKey(0) # waits until a key is pressed
    #cv2.destroyAllWindows()

#k=r'C:\Users\TEMP\Desktop\fog\SingleImageHazeRemover\sample\frame1.jpg'
#z=[]
for i in range(1,199):
    c=r'C:/Users/TEMP/Desktop/video12/frame'+str(i)+'.jpg'
    fogdet(c)

#k=r'C:\Users\TEMP\Desktop\fog\SingleImageHazeRemover\sample\ex_input'
#fogdet(k)
# Out:
# C:/Users/TEMP/Desktop/video12/frame1.jpg
# C:/Users/TEMP/Desktop/video12/frame2.jpg
# C:/Users/TEMP/Desktop/video12/frame3.jpg
# C:/Users/TEMP/Desktop/video12/frame4.jpg
# C:/Users/TEMP/Desktop/video12/frame5.jpg
# C:/Users/TEMP/Desktop/video12/frame6.jpg
# C:/Users/TEMP/Desktop/video12/frame7.jpg
# C:/Users/TEMP/Desktop/video12/frame8.jpg
# C:/Users/TEMP/Desktop/video12/frame9.jpg
# C:/Users/TEMP/Desktop/video12/frame10.jpg
# C:/Users/TEMP/Desktop/video12/frame11.jpg
# C:/Users/TEMP/Desktop/video12/frame12.jpg
# C:/Users/TEMP/Desktop/video12/frame13.jpg
# C:/Users/TEMP/Desktop/video12/frame14.jpg
# C:/Users/TEMP/Desktop/video12/frame15.jpg
# C:/Users/TEMP/Desktop/video12/frame16.jpg
# C:/Users/TEMP/Desktop/video12/frame17.jpg
# C:/Users/TEMP/Desktop/video12/frame18.jpg
# C:/Users/TEMP/Desktop/video12/frame19.jpg
# C:/Users/TEMP/Desktop/video12/frame20.jpg
# C:/Users/TEMP/Desktop/video12/frame21.jpg
# C:/Users/TEMP/Desktop/video12/frame22.jpg
# C:/Users/TEMP/Desktop/video12/frame23.jpg
# C:/Users/TEMP/Desktop/video12/frame24.jpg
# C:/Users/TEMP/Desktop/video12/frame25.jpg
# C:/Users/TEMP/Desktop/video12/frame26.jpg
# C:/Users/TEMP/Desktop/video12/frame27.jpg
# C:/Users/TEMP/Desktop/video12/frame28.jpg
# C:/Users/TEMP/Desktop/video12/frame29.jpg
# C:/Users/TEMP/Desktop/video12/frame30.jpg
# C:/Users/TEMP/Desktop/video12/frame31.jpg
# C:/Users/TEMP/Desktop/video12/frame32.jpg
# C:/Users/TEMP/Desktop/video12/frame33.jpg
# C:/Users/TEMP/Desktop/video12/frame34.jpg
# C:/Users/TEMP/Desktop/video12/frame35.jpg
# C:/Users/TEMP/Desktop/video12/frame36.jpg
# C:/Users/TEMP/Desktop/video12/frame37.jpg
# C:/Users/TEMP/Desktop/video12/frame38.jpg
# C:/Users/TEMP/Desktop/video12/frame39.jpg
# C:/Users/TEMP/Desktop/video12/frame40.jpg
# C:/Users/TEMP/Desktop/video12/frame41.jpg
# C:/Users/TEMP/Desktop/video12/frame42.jpg
# C:/Users/TEMP/Desktop/video12/frame43.jpg
# C:/Users/TEMP/Desktop/video12/frame44.jpg
# C:/Users/TEMP/Desktop/video12/frame45.jpg
# C:/Users/TEMP/Desktop/video12/frame46.jpg
# C:/Users/TEMP/Desktop/video12/frame47.jpg
# C:/Users/TEMP/Desktop/video12/frame48.jpg
# C:/Users/TEMP/Desktop/video12/frame49.jpg
# C:/Users/TEMP/Desktop/video12/frame50.jpg
# C:/Users/TEMP/Desktop/video12/frame51.jpg
# C:/Users/TEMP/Desktop/video12/frame52.jpg
# C:/Users/TEMP/Desktop/video12/frame53.jpg
# C:/Users/TEMP/Desktop/video12/frame54.jpg
# C:/Users/TEMP/Desktop/video12/frame55.jpg
# C:/Users/TEMP/Desktop/video12/frame56.jpg
# C:/Users/TEMP/Desktop/video12/frame57.jpg
# C:/Users/TEMP/Desktop/video12/frame58.jpg
# C:/Users/TEMP/Desktop/video12/frame59.jpg
# C:/Users/TEMP/Desktop/video12/frame60.jpg
# C:/Users/TEMP/Desktop/video12/frame61.jpg
# C:/Users/TEMP/Desktop/video12/frame62.jpg
# C:/Users/TEMP/Desktop/video12/frame63.jpg
# C:/Users/TEMP/Desktop/video12/frame64.jpg
# C:/Users/TEMP/Desktop/video12/frame65.jpg
# C:/Users/TEMP/Desktop/video12/frame66.jpg
# C:/Users/TEMP/Desktop/video12/frame67.jpg
# C:/Users/TEMP/Desktop/video12/frame68.jpg
# C:/Users/TEMP/Desktop/video12/frame69.jpg
# C:/Users/TEMP/Desktop/video12/frame70.jpg
# C:/Users/TEMP/Desktop/video12/frame71.jpg
# C:/Users/TEMP/Desktop/video12/frame72.jpg
# C:/Users/TEMP/Desktop/video12/frame73.jpg
# C:/Users/TEMP/Desktop/video12/frame74.jpg
# C:/Users/TEMP/Desktop/video12/frame75.jpg
# C:/Users/TEMP/Desktop/video12/frame76.jpg
# C:/Users/TEMP/Desktop/video12/frame77.jpg
# C:/Users/TEMP/Desktop/video12/frame78.jpg
# C:/Users/TEMP/Desktop/video12/frame79.jpg
# C:/Users/TEMP/Desktop/video12/frame80.jpg
# C:/Users/TEMP/Desktop/video12/frame81.jpg
# C:/Users/TEMP/Desktop/video12/frame82.jpg
# C:/Users/TEMP/Desktop/video12/frame83.jpg
# C:/Users/TEMP/Desktop/video12/frame84.jpg
# C:/Users/TEMP/Desktop/video12/frame85.jpg
# C:/Users/TEMP/Desktop/video12/frame86.jpg
# C:/Users/TEMP/Desktop/video12/frame87.jpg
# C:/Users/TEMP/Desktop/video12/frame88.jpg
# C:/Users/TEMP/Desktop/video12/frame89.jpg
# C:/Users/TEMP/Desktop/video12/frame90.jpg
# C:/Users/TEMP/Desktop/video12/frame91.jpg
# C:/Users/TEMP/Desktop/video12/frame92.jpg
# C:/Users/TEMP/Desktop/video12/frame93.jpg
# C:/Users/TEMP/Desktop/video12/frame94.jpg
# C:/Users/TEMP/Desktop/video12/frame95.jpg
# C:/Users/TEMP/Desktop/video12/frame96.jpg
# C:/Users/TEMP/Desktop/video12/frame97.jpg
# C:/Users/TEMP/Desktop/video12/frame98.jpg
# C:/Users/TEMP/Desktop/video12/frame99.jpg
# C:/Users/TEMP/Desktop/video12/frame100.jpg
# C:/Users/TEMP/Desktop/video12/frame101.jpg
# C:/Users/TEMP/Desktop/video12/frame102.jpg
# C:/Users/TEMP/Desktop/video12/frame103.jpg
# C:/Users/TEMP/Desktop/video12/frame104.jpg
# C:/Users/TEMP/Desktop/video12/frame105.jpg
# C:/Users/TEMP/Desktop/video12/frame106.jpg
# C:/Users/TEMP/Desktop/video12/frame107.jpg
# C:/Users/TEMP/Desktop/video12/frame108.jpg
# C:/Users/TEMP/Desktop/video12/frame109.jpg
# C:/Users/TEMP/Desktop/video12/frame110.jpg
# C:/Users/TEMP/Desktop/video12/frame111.jpg
# C:/Users/TEMP/Desktop/video12/frame112.jpg
# C:/Users/TEMP/Desktop/video12/frame113.jpg
# C:/Users/TEMP/Desktop/video12/frame114.jpg
# C:/Users/TEMP/Desktop/video12/frame115.jpg
# C:/Users/TEMP/Desktop/video12/frame116.jpg
# C:/Users/TEMP/Desktop/video12/frame117.jpg
# C:/Users/TEMP/Desktop/video12/frame118.jpg
# C:/Users/TEMP/Desktop/video12/frame119.jpg
# C:/Users/TEMP/Desktop/video12/frame120.jpg
# C:/Users/TEMP/Desktop/video12/frame121.jpg
# C:/Users/TEMP/Desktop/video12/frame122.jpg
# C:/Users/TEMP/Desktop/video12/frame123.jpg
# C:/Users/TEMP/Desktop/video12/frame124.jpg
# C:/Users/TEMP/Desktop/video12/frame125.jpg
# C:/Users/TEMP/Desktop/video12/frame126.jpg
# C:/Users/TEMP/Desktop/video12/frame127.jpg
# C:/Users/TEMP/Desktop/video12/frame128.jpg
# C:/Users/TEMP/Desktop/video12/frame129.jpg
# C:/Users/TEMP/Desktop/video12/frame130.jpg
# C:/Users/TEMP/Desktop/video12/frame131.jpg
# C:/Users/TEMP/Desktop/video12/frame132.jpg
# C:/Users/TEMP/Desktop/video12/frame133.jpg
# C:/Users/TEMP/Desktop/video12/frame134.jpg
# C:/Users/TEMP/Desktop/video12/frame135.jpg
# C:/Users/TEMP/Desktop/video12/frame136.jpg
# C:/Users/TEMP/Desktop/video12/frame137.jpg
# C:/Users/TEMP/Desktop/video12/frame138.jpg
# C:/Users/TEMP/Desktop/video12/frame139.jpg
# C:/Users/TEMP/Desktop/video12/frame140.jpg
# C:/Users/TEMP/Desktop/video12/frame141.jpg
# C:/Users/TEMP/Desktop/video12/frame142.jpg
# C:/Users/TEMP/Desktop/video12/frame143.jpg
# C:/Users/TEMP/Desktop/video12/frame144.jpg
# C:/Users/TEMP/Desktop/video12/frame145.jpg
# C:/Users/TEMP/Desktop/video12/frame146.jpg
# C:/Users/TEMP/Desktop/video12/frame147.jpg
# C:/Users/TEMP/Desktop/video12/frame148.jpg
# C:/Users/TEMP/Desktop/video12/frame149.jpg
# C:/Users/TEMP/Desktop/video12/frame150.jpg
# C:/Users/TEMP/Desktop/video12/frame151.jpg
# C:/Users/TEMP/Desktop/video12/frame152.jpg
# C:/Users/TEMP/Desktop/video12/frame153.jpg
# C:/Users/TEMP/Desktop/video12/frame154.jpg
# C:/Users/TEMP/Desktop/video12/frame155.jpg
# C:/Users/TEMP/Desktop/video12/frame156.jpg
# C:/Users/TEMP/Desktop/video12/frame157.jpg
# C:/Users/TEMP/Desktop/video12/frame158.jpg
# C:/Users/TEMP/Desktop/video12/frame159.jpg
# C:/Users/TEMP/Desktop/video12/frame160.jpg
# C:/Users/TEMP/Desktop/video12/frame161.jpg
# C:/Users/TEMP/Desktop/video12/frame162.jpg
# C:/Users/TEMP/Desktop/video12/frame163.jpg
# C:/Users/TEMP/Desktop/video12/frame164.jpg
# C:/Users/TEMP/Desktop/video12/frame165.jpg
# C:/Users/TEMP/Desktop/video12/frame166.jpg
# C:/Users/TEMP/Desktop/video12/frame167.jpg
# C:/Users/TEMP/Desktop/video12/frame168.jpg
# C:/Users/TEMP/Desktop/video12/frame169.jpg
# C:/Users/TEMP/Desktop/video12/frame170.jpg
# C:/Users/TEMP/Desktop/video12/frame171.jpg
# C:/Users/TEMP/Desktop/video12/frame172.jpg
# C:/Users/TEMP/Desktop/video12/frame173.jpg
# C:/Users/TEMP/Desktop/video12/frame174.jpg
# C:/Users/TEMP/Desktop/video12/frame175.jpg
# C:/Users/TEMP/Desktop/video12/frame176.jpg
# C:/Users/TEMP/Desktop/video12/frame177.jpg
# C:/Users/TEMP/Desktop/video12/frame178.jpg
# C:/Users/TEMP/Desktop/video12/frame179.jpg
# C:/Users/TEMP/Desktop/video12/frame180.jpg
# C:/Users/TEMP/Desktop/video12/frame181.jpg
# C:/Users/TEMP/Desktop/video12/frame182.jpg
# C:/Users/TEMP/Desktop/video12/frame183.jpg
# C:/Users/TEMP/Desktop/video12/frame184.jpg
# C:/Users/TEMP/Desktop/video12/frame185.jpg
# C:/Users/TEMP/Desktop/video12/frame186.jpg
# C:/Users/TEMP/Desktop/video12/frame187.jpg
# C:/Users/TEMP/Desktop/video12/frame188.jpg
# C:/Users/TEMP/Desktop/video12/frame189.jpg
# C:/Users/TEMP/Desktop/video12/frame190.jpg
# C:/Users/TEMP/Desktop/video12/frame191.jpg
# C:/Users/TEMP/Desktop/video12/frame192.jpg
# C:/Users/TEMP/Desktop/video12/frame193.jpg
# C:/Users/TEMP/Desktop/video12/frame194.jpg
# C:/Users/TEMP/Desktop/video12/frame195.jpg
# C:/Users/TEMP/Desktop/video12/frame196.jpg
# C:/Users/TEMP/Desktop/video12/frame197.jpg
# C:/Users/TEMP/Desktop/video12/frame198.jpg
