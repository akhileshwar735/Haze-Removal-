# %%
"""Single image dehazing."""
from __future__ import division
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

class Channel_value:
    val = -1.0
    intensity = -1.0


def find_intensity_of_atmospheric_light(img, gray):
    top_num = int(img.shape[0] * img.shape[1] * 0.001)
    toplist = [Channel_value()] * top_num
    dark_channel = find_dark_channel(img)

    for y in range(img.shape[0]):
        for x in range(img.shape[1]):
            val = img.item(y, x, dark_channel)
            intensity = gray.item(y, x)
            for t in toplist:
                if t.val < val or (t.val == val and t.intensity < intensity):
                    t.val = val
                    t.intensity = intensity
                    break

    max_channel = Channel_value()
    for t in toplist:
        if t.intensity > max_channel.intensity:
            max_channel = t

    return max_channel.intensity


def find_dark_channel(img):
    return np.unravel_index(np.argmin(img), img.shape)[2]


def clamp(minimum, x, maximum):
    return max(minimum, min(x, maximum))


def dehaze(img, light_intensity, windowSize, t0, w):
    size = (img.shape[0], img.shape[1])

    outimg = np.zeros(img.shape, img.dtype)

    for y in range(size[0]):
        for x in range(size[1]):
            x_low = max(x-(windowSize//2), 0)
            y_low = max(y-(windowSize//2), 0)
            x_high = min(x+(windowSize//2), size[1])
            y_high = min(y+(windowSize//2), size[0])

            sliceimg = img[y_low:y_high, x_low:x_high]

            dark_channel = find_dark_channel(sliceimg)
            t = 1.0 - (w * img.item(y, x, dark_channel) / light_intensity)

            outimg.itemset((y,x,0), clamp(0, ((img.item(y,x,0) - light_intensity) / max(t, t0) + light_intensity), 255))
            outimg.itemset((y,x,1), clamp(0, ((img.item(y,x,1) - light_intensity) / max(t, t0) + light_intensity), 255))
            outimg.itemset((y,x,2), clamp(0, ((img.item(y,x,2) - light_intensity) / max(t, t0) + light_intensity), 255))
    return outimg


def main():
    imageName = r'C:\Users\TEMP\Desktop\fog\SingleImageHazeRemover\sample\ex_input.jpg' #eg. fg5.jpg
    img = cv2.imread(imageName)
    print(imageName)
    #cv2.namedWindow('name')
    cv2.namedWindow("result", cv2.WINDOW_AUTOSIZE)
    #gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    light_intensity = find_intensity_of_atmospheric_light(img, gray)
    w = 0.95
    t0 = 0.55
    outimg = dehaze(img, light_intensity, 20, t0, w)
    name = imageName+'_out_t0'+str(t0)+'_w'+str(w)+'.jpg'
    roh = mpimg.imread(r'C:\Users\TEMP\Desktop\fog\SingleImageHazeRemover\sample\ex_input.jpg_out_t00.55_w0.95.jpg')
    imgplot = plt.imshow(roh)
    cv2.imwrite(name, outimg)

if __name__ == "__main__": main()
# Out:
# C:\Users\TEMP\Desktop\fog\SingleImageHazeRemover\sample\ex_input.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-b6a5318e86bb> in <module>()
#      83     cv2.imwrite(name, outimg)
#      84
# ---> 85 if __name__ == "__main__": main()
#
# <ipython-input-1-b6a5318e86bb> in main()
#      79     outimg = dehaze(img, light_intensity, 20, t0, w)
#      80     name = imageName+'_out_t0'+str(t0)+'_w'+str(w)+'.jpg'
# ---> 81     roh = mpimg.imread(r'C:\Users\TEMP\Desktop\fog\SingleImageHazeRemover\sample\ex_input.jpg_out_t00.55_w0.95.jpg')
#      82     imgplot = plt.imshow(roh)
#      83     cv2.imwrite(name, outimg)
#
# C:\Users\Public\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1354
#    1355     if ext not in handlers:
# -> 1356         im = pilread(fname)
#    1357         if im is None:
#    1358             raise ValueError('Only know how to handle extensions: %s; '
#
# C:\Users\Public\Anaconda3\lib\site-packages\matplotlib\image.py in pilread(fname)
#    1332         except ImportError:
#    1333             return None
# -> 1334         with Image.open(fname) as image:
#    1335             return pil_to_array(image)
#    1336
#
# C:\Users\Public\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2541
#    2542     if filename:
# -> 2543         fp = builtins.open(filename, "rb")
#    2544         exclusive_fp = True
#    2545
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\TEMP\\Desktop\\fog\\SingleImageHazeRemover\\sample\\ex_input.jpg_out_t00.55_w0.95.jpg'

# %%
import cv2 
import numpy as np
import os
   
# Create a VideoCapture object and read from input file 
cap = cv2.VideoCapture(r'C:\Users\TEMP\Desktop\figdp\481479901 (online-video-cutter.com) (1).mp4') 
   
# Check if camera opened successfully 
if (cap.isOpened()== False):  
    print("Error opening video  file") 
   
# Read until video is completed
count=1
while(cap.isOpened()): 
  # Capture frame-by-frame 
    ret, frame = cap.read() 
    if ret == True: 
   
    # Display the resulting frame 
        print('Read %d frame: ' % count, ret)
        cv2.imwrite(os.path.join(r'C:\Users\TEMP\Desktop\video12', "frame{:d}.jpg".format(count)), frame)
        count += 1
   
  # Break the loop 
    else:  
        break
   
# When everything done, release  
# the video capture object 
cap.release()
   
# Closes all the frames 
cv2.destroyAllWindows()
# Out:
# Read 1 frame:  True
# Read 2 frame:  True
# Read 3 frame:  True
# Read 4 frame:  True
# Read 5 frame:  True
# Read 6 frame:  True
# Read 7 frame:  True
# Read 8 frame:  True
# Read 9 frame:  True
# Read 10 frame:  True
# Read 11 frame:  True
# Read 12 frame:  True
# Read 13 frame:  True
# Read 14 frame:  True
# Read 15 frame:  True
# Read 16 frame:  True
# Read 17 frame:  True
# Read 18 frame:  True
# Read 19 frame:  True
# Read 20 frame:  True
# Read 21 frame:  True
# Read 22 frame:  True
# Read 23 frame:  True
# Read 24 frame:  True
# Read 25 frame:  True
# Read 26 frame:  True
# Read 27 frame:  True
# Read 28 frame:  True
# Read 29 frame:  True
# Read 30 frame:  True
# Read 31 frame:  True
# Read 32 frame:  True
# Read 33 frame:  True
# Read 34 frame:  True
# Read 35 frame:  True
# Read 36 frame:  True
# Read 37 frame:  True
# Read 38 frame:  True
# Read 39 frame:  True
# Read 40 frame:  True
# Read 41 frame:  True
# Read 42 frame:  True
# Read 43 frame:  True
# Read 44 frame:  True
# Read 45 frame:  True
# Read 46 frame:  True
# Read 47 frame:  True
# Read 48 frame:  True
# Read 49 frame:  True
# Read 50 frame:  True
# Read 51 frame:  True
# Read 52 frame:  True
# Read 53 frame:  True
# Read 54 frame:  True
# Read 55 frame:  True
# Read 56 frame:  True
# Read 57 frame:  True
# Read 58 frame:  True
# Read 59 frame:  True
# Read 60 frame:  True
# Read 61 frame:  True
# Read 62 frame:  True
# Read 63 frame:  True
# Read 64 frame:  True
# Read 65 frame:  True
# Read 66 frame:  True
# Read 67 frame:  True
# Read 68 frame:  True
# Read 69 frame:  True
# Read 70 frame:  True
# Read 71 frame:  True
# Read 72 frame:  True
# Read 73 frame:  True
# Read 74 frame:  True
# Read 75 frame:  True
# Read 76 frame:  True
# Read 77 frame:  True
# Read 78 frame:  True
# Read 79 frame:  True
# Read 80 frame:  True
# Read 81 frame:  True
# Read 82 frame:  True
# Read 83 frame:  True
# Read 84 frame:  True
# Read 85 frame:  True
# Read 86 frame:  True
# Read 87 frame:  True
# Read 88 frame:  True
# Read 89 frame:  True
# Read 90 frame:  True
# Read 91 frame:  True
# Read 92 frame:  True
# Read 93 frame:  True
# Read 94 frame:  True
# Read 95 frame:  True
# Read 96 frame:  True
# Read 97 frame:  True
# Read 98 frame:  True
# Read 99 frame:  True
# Read 100 frame:  True
# Read 101 frame:  True
# Read 102 frame:  True
# Read 103 frame:  True
# Read 104 frame:  True
# Read 105 frame:  True
# Read 106 frame:  True
# Read 107 frame:  True
# Read 108 frame:  True
# Read 109 frame:  True
# Read 110 frame:  True
# Read 111 frame:  True
# Read 112 frame:  True
# Read 113 frame:  True
# Read 114 frame:  True
# Read 115 frame:  True
# Read 116 frame:  True
# Read 117 frame:  True
# Read 118 frame:  True
# Read 119 frame:  True
# Read 120 frame:  True
# Read 121 frame:  True
# Read 122 frame:  True
# Read 123 frame:  True
# Read 124 frame:  True
# Read 125 frame:  True
# Read 126 frame:  True
# Read 127 frame:  True
# Read 128 frame:  True
# Read 129 frame:  True
# Read 130 frame:  True
# Read 131 frame:  True
# Read 132 frame:  True
# Read 133 frame:  True
# Read 134 frame:  True
# Read 135 frame:  True
# Read 136 frame:  True
# Read 137 frame:  True
# Read 138 frame:  True
# Read 139 frame:  True
# Read 140 frame:  True
# Read 141 frame:  True
# Read 142 frame:  True
# Read 143 frame:  True
# Read 144 frame:  True
# Read 145 frame:  True
# Read 146 frame:  True
# Read 147 frame:  True
# Read 148 frame:  True
# Read 149 frame:  True
# Read 150 frame:  True
# Read 151 frame:  True
# Read 152 frame:  True
# Read 153 frame:  True
# Read 154 frame:  True
# Read 155 frame:  True
# Read 156 frame:  True
# Read 157 frame:  True
# Read 158 frame:  True
# Read 159 frame:  True
# Read 160 frame:  True
# Read 161 frame:  True
# Read 162 frame:  True
# Read 163 frame:  True
# Read 164 frame:  True
# Read 165 frame:  True
# Read 166 frame:  True
# Read 167 frame:  True
# Read 168 frame:  True
# Read 169 frame:  True
# Read 170 frame:  True
# Read 171 frame:  True
# Read 172 frame:  True
# Read 173 frame:  True
# Read 174 frame:  True
# Read 175 frame:  True
# Read 176 frame:  True
# Read 177 frame:  True
# Read 178 frame:  True
# Read 179 frame:  True
# Read 180 frame:  True
# Read 181 frame:  True
# Read 182 frame:  True
# Read 183 frame:  True
# Read 184 frame:  True
# Read 185 frame:  True
# Read 186 frame:  True
# Read 187 frame:  True
# Read 188 frame:  True
# Read 189 frame:  True
# Read 190 frame:  True
# Read 191 frame:  True
# Read 192 frame:  True
# Read 193 frame:  True
# Read 194 frame:  True
# Read 195 frame:  True
# Read 196 frame:  True
# Read 197 frame:  True
# Read 198 frame:  True
# Read 199 frame:  True
# Read 200 frame:  True
# Read 201 frame:  True
# Read 202 frame:  True
# Read 203 frame:  True
# Read 204 frame:  True
# Read 205 frame:  True
# Read 206 frame:  True
# Read 207 frame:  True
# Read 208 frame:  True
# Read 209 frame:  True
# Read 210 frame:  True
# Read 211 frame:  True
# Read 212 frame:  True
# Read 213 frame:  True
# Read 214 frame:  True
# Read 215 frame:  True
# Read 216 frame:  True
# Read 217 frame:  True
# Read 218 frame:  True
# Read 219 frame:  True
# Read 220 frame:  True
# Read 221 frame:  True
# Read 222 frame:  True
# Read 223 frame:  True
# Read 224 frame:  True
# Read 225 frame:  True
# Read 226 frame:  True
# Read 227 frame:  True
# Read 228 frame:  True
# Read 229 frame:  True
# Read 230 frame:  True
# Read 231 frame:  True
# Read 232 frame:  True
# Read 233 frame:  True
# Read 234 frame:  True
# Read 235 frame:  True
# Read 236 frame:  True
# Read 237 frame:  True
# Read 238 frame:  True
# Read 239 frame:  True
# Read 240 frame:  True
# Read 241 frame:  True
# Read 242 frame:  True
# Read 243 frame:  True
# Read 244 frame:  True
# Read 245 frame:  True
# Read 246 frame:  True
# Read 247 frame:  True
# Read 248 frame:  True
# Read 249 frame:  True
# Read 250 frame:  True
# Read 251 frame:  True
# Read 252 frame:  True
# Read 253 frame:  True
# Read 254 frame:  True
# Read 255 frame:  True
# Read 256 frame:  True
# Read 257 frame:  True
# Read 258 frame:  True
# Read 259 frame:  True
# Read 260 frame:  True
# Read 261 frame:  True
# Read 262 frame:  True
# Read 263 frame:  True
# Read 264 frame:  True
